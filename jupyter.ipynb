# %%
import pandas as panda
import matplotlib.pyplot as plt
import numpy as np

data_frame=panda.DataFrame({
    'Names':['joesky','mike','brayo'],
    'Age':[2,4,6],
    'sex':['male','male','male']
})
x = np.linspace(0, 2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.
# with plt.style.context('dark_background'):
#     plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
# plt.show()


# print(data_frame['Age']())
# fig, ax = plt.subplots() 
# plt.plot([2,3,4,5],[100,200,400,600]) # Create a figure containing a single axes.
# ax.plot([x for x in data_frame['Age']], [1, 4, 2, ])  # Plot some data on the axes.

# students=panda.read_csv("Marks-pro.csv") 

# print(students['Stream'])
